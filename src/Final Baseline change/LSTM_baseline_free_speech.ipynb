# %%
import numpy as np
from torch.utils import data
from torch.utils.data import Dataset
from torch.utils.data.sampler import SubsetRandomSampler
from sklearn import preprocessing
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import _LRScheduler

torch.backends.cudnn.deterministic = True

class Dataset(data.Dataset):
    def __init__(self, X1, Y1):
        self.X1 = X1
        self.Y1 = Y1

    def __len__(self):
        return len(self.X1)

    def __getitem__(self, index):
        x = self.X1[index]
        y1 = self.Y1[index]
        return x, y1

train_features=np.load("../extracted_features/FS-change3/input_features_free_train.npy")
labels_stress_train=np.load("../extracted_features/FS-change3/label_free_train.npy")


test_features=np.load("../extracted_features/FS-change3/input_features_free_test.npy")
labels_stress_test=np.load("../extracted_features/FS-change3/label_free_test.npy")


val_features=np.load("../extracted_features/FS-change3/input_features_free_val.npy")
labels_stress_val=np.load("../extracted_features/FS-change3/label_free_val.npy")

# %%
print(labels_stress_train.shape,labels_stress_train)
# Out:
# (1121,) [0. 0. 0. ... 1. 1. 1.]

# %%
batch_size=20
train_data = Dataset(train_features, labels_stress_train)
test_data=Dataset(test_features,labels_stress_test)
val_data=Dataset(val_features,labels_stress_val)
train_data_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size)
val_data_loader=DataLoader(test_data,shuffle=True,batch_size=batch_size)
test_data_loader=DataLoader(val_data,shuffle=True,batch_size=batch_size)

# %%
class CyclicLR(_LRScheduler):
    
    def __init__(self, optimizer, schedule, last_epoch=-1):
        assert callable(schedule)
        self.schedule = schedule
        super().__init__(optimizer, last_epoch)

    def get_lr(self):
        return [self.schedule(self.last_epoch, lr) for lr in self.base_lrs]

# %%
def cosine(t_max, eta_min=0):
    
    def scheduler(epoch, base_lr):
        t = epoch % t_max
        return eta_min + (base_lr - eta_min)*(1 + np.cos(np.pi*t/t_max))/2
    
    return scheduler

# %%
class Classifier(nn.Module):
    
    def __init__(self):
        super().__init__()
        self.input_dim = 8
        self.hidden_dim = 200
        self.layer_dim = 1
        self.output_dim=1
        self.rnn = nn.LSTM(self.input_dim, self.hidden_dim, self.layer_dim, batch_first=True)
        self.fc = nn.Linear(self.hidden_dim, self.output_dim)
        self.sig=nn.Sigmoid()
    
    def forward(self, x):
        h0, c0 = self.init_hidden(x)
        out, (hn, cn) = self.rnn(x, (h0, c0))
        out = self.fc(out[:, -1, :])
        out=self.sig(out)
        return out
    
    def init_hidden(self, x):
        h0 = torch.zeros(self.layer_dim, x.size(0), self.hidden_dim)
        c0 = torch.zeros(self.layer_dim, x.size(0), self.hidden_dim)
        return [t.cuda() for t in (h0, c0)]

# %%
feature_size = 8
shared_layer_size = 512
LR = 0.0001
epoch = 200
model=Classifier()
model.cuda()
iterations_per_epoch = len(train_data_loader)
loss_func = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LR)
sched = CyclicLR(optimizer, cosine(t_max=iterations_per_epoch * 2, eta_min=LR/100))

# %%
from sklearn.metrics import accuracy_score
best_acc1 = 0
modelname=[]
truth=[]
preds=[]

for it in range(epoch+1):
    model.train()
    total=len(train_data_loader)*batch_size
    train_loss = 0.
    for minibatch in train_data_loader:
        X, Y1  = minibatch
        X=X.cuda()
        Y1=Y1.cuda()
        output = model(X.float())
        output=output.squeeze(1)
        loss = loss_func(output, Y1.float())
        Y_hat1 = torch.ge(output, 0.5).float()
        train_loss += loss.item()
        truth.extend(Y1.tolist())
        preds.extend(Y_hat1.tolist())
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        sched.step()
    trainacc1=accuracy_score(truth,preds)
    train_loss /= total
    print("EPOCH ",it)
    print('Train : Loss: {:.4f}, Train acc1 : {:.4f}'.format(train_loss,trainacc1))
    
    count=0
    val_loss= 0.
    truth=[]
    preds=[]
    total=len(val_data_loader)*batch_size
    model.eval()    
    for minibatch in val_data_loader:
        X_valid, Y1_valid  = minibatch
        X_valid=X_valid.cuda()
        Y1_valid=Y1_valid.cuda()
        output_val = model(X_valid.float())
        output_val=output_val.squeeze(1)
        loss = loss_func(output_val, Y1_valid.float())
        Y_hat1_val = torch.ge(output_val, 0.5).float()
        val_loss += loss.item()
        truth.extend(Y1_valid.tolist())
        preds.extend(Y_hat1_val.tolist())
    valacc1=accuracy_score(truth,preds)
    val_loss /= total
    print('Val : Loss: {:.4f}, Val acc1 : {:.4f}'.format(val_loss,valacc1))
    if valacc1 >= best_acc1:
        best_acc1 = valacc1
        best_state = model.state_dict()
        print('Best validation accuracy1 ', best_acc1)
# Out:
# EPOCH  0
# Train : Loss: 0.0340, Train acc1 : 0.5709
# Val : Loss: 0.0384, Val acc1 : 0.3053
# Best validation accuracy1  0.30526315789473685
# EPOCH  1
# Train : Loss: 0.0332, Train acc1 : 0.5728
# Val : Loss: 0.0389, Val acc1 : 0.3000
# EPOCH  2
# Train : Loss: 0.0328, Train acc1 : 0.5828
# Val : Loss: 0.0401, Val acc1 : 0.3105
# Best validation accuracy1  0.3105263157894737
# EPOCH  3
# Train : Loss: 0.0322, Train acc1 : 0.5957
# Val : Loss: 0.0407, Val acc1 : 0.3158
# Best validation accuracy1  0.3157894736842105
# EPOCH  4
# Train : Loss: 0.0321, Train acc1 : 0.5988
# Val : Loss: 0.0421, Val acc1 : 0.3000
# EPOCH  5
# Train : Loss: 0.0316, Train acc1 : 0.6011
# Val : Loss: 0.0433, Val acc1 : 0.3000
# EPOCH  6
# Train : Loss: 0.0313, Train acc1 : 0.6003
# Val : Loss: 0.0441, Val acc1 : 0.2947
# EPOCH  7
# Train : Loss: 0.0309, Train acc1 : 0.6011
# Val : Loss: 0.0446, Val acc1 : 0.2947
# EPOCH  8
# Train : Loss: 0.0310, Train acc1 : 0.6102
# Val : Loss: 0.0463, Val acc1 : 0.3158
# Best validation accuracy1  0.3157894736842105
# EPOCH  9
# Train : Loss: 0.0300, Train acc1 : 0.6194
# Val : Loss: 0.0455, Val acc1 : 0.3211
# Best validation accuracy1  0.32105263157894737
# EPOCH  10
# Train : Loss: 0.0300, Train acc1 : 0.6201
# Val : Loss: 0.0473, Val acc1 : 0.3316
# Best validation accuracy1  0.33157894736842103
# EPOCH  11
# Train : Loss: 0.0294, Train acc1 : 0.6278
# Val : Loss: 0.0475, Val acc1 : 0.3368
# Best validation accuracy1  0.3368421052631579
# EPOCH  12
# Train : Loss: 0.0295, Train acc1 : 0.6262
# Val : Loss: 0.0496, Val acc1 : 0.3474
# Best validation accuracy1  0.3473684210526316
# EPOCH  13
# Train : Loss: 0.0286, Train acc1 : 0.6369
# Val : Loss: 0.0500, Val acc1 : 0.3316
# EPOCH  14
# Train : Loss: 0.0296, Train acc1 : 0.6346
# Val : Loss: 0.0519, Val acc1 : 0.3684
# Best validation accuracy1  0.3684210526315789
# EPOCH  15
# Train : Loss: 0.0284, Train acc1 : 0.6499
# Val : Loss: 0.0487, Val acc1 : 0.3474
# EPOCH  16
# Train : Loss: 0.0284, Train acc1 : 0.6568
# Val : Loss: 0.0514, Val acc1 : 0.3579
# EPOCH  17
# Train : Loss: 0.0275, Train acc1 : 0.6568
# Val : Loss: 0.0525, Val acc1 : 0.3474
# EPOCH  18
# Train : Loss: 0.0272, Train acc1 : 0.6636
# Val : Loss: 0.0531, Val acc1 : 0.3526
# EPOCH  19
# Train : Loss: 0.0269, Train acc1 : 0.6606
# Val : Loss: 0.0530, Val acc1 : 0.3632
# EPOCH  20
# Train : Loss: 0.0268, Train acc1 : 0.6659
# Val : Loss: 0.0542, Val acc1 : 0.3474
# EPOCH  21
# Train : Loss: 0.0265, Train acc1 : 0.6751
# Val : Loss: 0.0534, Val acc1 : 0.3579
# EPOCH  22
# Train : Loss: 0.0265, Train acc1 : 0.6651
# Val : Loss: 0.0555, Val acc1 : 0.3474
# EPOCH  23
# Train : Loss: 0.0273, Train acc1 : 0.6659
# Val : Loss: 0.0554, Val acc1 : 0.3684
# Best validation accuracy1  0.3684210526315789
# EPOCH  24
# Train : Loss: 0.0262, Train acc1 : 0.6735
# Val : Loss: 0.0533, Val acc1 : 0.3579
# EPOCH  25
# Train : Loss: 0.0259, Train acc1 : 0.6751
# Val : Loss: 0.0550, Val acc1 : 0.3632
# EPOCH  26
# Train : Loss: 0.0262, Train acc1 : 0.6819
# Val : Loss: 0.0574, Val acc1 : 0.3842
# Best validation accuracy1  0.38421052631578945
# EPOCH  27
# Train : Loss: 0.0266, Train acc1 : 0.6819
# Val : Loss: 0.0544, Val acc1 : 0.3526
# EPOCH  28
# Train : Loss: 0.0261, Train acc1 : 0.6674
# Val : Loss: 0.0544, Val acc1 : 0.3737
# EPOCH  29
# Train : Loss: 0.0261, Train acc1 : 0.6827
# Val : Loss: 0.0560, Val acc1 : 0.3684
# EPOCH  30
# Train : Loss: 0.0263, Train acc1 : 0.6796
# Val : Loss: 0.0537, Val acc1 : 0.3789
# EPOCH  31
# Train : Loss: 0.0258, Train acc1 : 0.6987
# Val : Loss: 0.0550, Val acc1 : 0.3632
# EPOCH  32
# Train : Loss: 0.0258, Train acc1 : 0.6873
# Val : Loss: 0.0572, Val acc1 : 0.3684
# EPOCH  33
# Train : Loss: 0.0249, Train acc1 : 0.6987
# Val : Loss: 0.0556, Val acc1 : 0.3842
# Best validation accuracy1  0.38421052631578945
# EPOCH  34
# Train : Loss: 0.0254, Train acc1 : 0.6911
# Val : Loss: 0.0550, Val acc1 : 0.4000
# Best validation accuracy1  0.4
# EPOCH  35
# Train : Loss: 0.0244, Train acc1 : 0.7040
# Val : Loss: 0.0557, Val acc1 : 0.3895
# EPOCH  36
# Train : Loss: 0.0247, Train acc1 : 0.6926
# Val : Loss: 0.0554, Val acc1 : 0.4105
# Best validation accuracy1  0.4105263157894737
# EPOCH  37
# Train : Loss: 0.0247, Train acc1 : 0.7086
# Val : Loss: 0.0559, Val acc1 : 0.3947
# EPOCH  38
# Train : Loss: 0.0241, Train acc1 : 0.7025
# Val : Loss: 0.0567, Val acc1 : 0.3789
# EPOCH  39
# Train : Loss: 0.0236, Train acc1 : 0.7002
# Val : Loss: 0.0568, Val acc1 : 0.4000
# EPOCH  40
# Train : Loss: 0.0238, Train acc1 : 0.7079
# Val : Loss: 0.0553, Val acc1 : 0.3895
# EPOCH  41
# Train : Loss: 0.0231, Train acc1 : 0.7079
# Val : Loss: 0.0585, Val acc1 : 0.3895
# EPOCH  42
# Train : Loss: 0.0239, Train acc1 : 0.7071
# Val : Loss: 0.0553, Val acc1 : 0.4105
# Best validation accuracy1  0.4105263157894737
# EPOCH  43
# Train : Loss: 0.0235, Train acc1 : 0.7109
# Val : Loss: 0.0563, Val acc1 : 0.4211
# Best validation accuracy1  0.42105263157894735
# EPOCH  44
# Train : Loss: 0.0231, Train acc1 : 0.7147
# Val : Loss: 0.0552, Val acc1 : 0.4105
# EPOCH  45
# Train : Loss: 0.0228, Train acc1 : 0.7239
# Val : Loss: 0.0579, Val acc1 : 0.4053
# EPOCH  46
# Train : Loss: 0.0228, Train acc1 : 0.7239
# Val : Loss: 0.0583, Val acc1 : 0.4263
# Best validation accuracy1  0.4263157894736842
# EPOCH  47
# Train : Loss: 0.0223, Train acc1 : 0.7307
# Val : Loss: 0.0580, Val acc1 : 0.4105
# EPOCH  48
# Train : Loss: 0.0227, Train acc1 : 0.7208
# Val : Loss: 0.0581, Val acc1 : 0.4053
# EPOCH  49
# Train : Loss: 0.0218, Train acc1 : 0.7285
# Val : Loss: 0.0604, Val acc1 : 0.4053
# EPOCH  50
# Train : Loss: 0.0238, Train acc1 : 0.7185
# Val : Loss: 0.0580, Val acc1 : 0.4474
# Best validation accuracy1  0.4473684210526316
# EPOCH  51
# Train : Loss: 0.0218, Train acc1 : 0.7361
# Val : Loss: 0.0564, Val acc1 : 0.4158
# EPOCH  52
# Train : Loss: 0.0223, Train acc1 : 0.7292
# Val : Loss: 0.0603, Val acc1 : 0.4053
# EPOCH  53
# Train : Loss: 0.0214, Train acc1 : 0.7407
# Val : Loss: 0.0608, Val acc1 : 0.3895
# EPOCH  54
# Train : Loss: 0.0224, Train acc1 : 0.7277
# Val : Loss: 0.0603, Val acc1 : 0.4105
# EPOCH  55
# Train : Loss: 0.0211, Train acc1 : 0.7460
# Val : Loss: 0.0593, Val acc1 : 0.4105
# EPOCH  56
# Train : Loss: 0.0207, Train acc1 : 0.7376
# Val : Loss: 0.0593, Val acc1 : 0.4263
# EPOCH  57
# Train : Loss: 0.0204, Train acc1 : 0.7529
# Val : Loss: 0.0629, Val acc1 : 0.4105
# EPOCH  58
# Train : Loss: 0.0213, Train acc1 : 0.7445
# Val : Loss: 0.0616, Val acc1 : 0.4053
# EPOCH  59
# Train : Loss: 0.0201, Train acc1 : 0.7582
# Val : Loss: 0.0596, Val acc1 : 0.4105
# EPOCH  60
# Train : Loss: 0.0204, Train acc1 : 0.7429
# Val : Loss: 0.0620, Val acc1 : 0.4158
# EPOCH  61
# Train : Loss: 0.0196, Train acc1 : 0.7628
# Val : Loss: 0.0625, Val acc1 : 0.4211
# EPOCH  62
# Train : Loss: 0.0197, Train acc1 : 0.7613
# Val : Loss: 0.0600, Val acc1 : 0.4105
# EPOCH  63
# Train : Loss: 0.0192, Train acc1 : 0.7582
# Val : Loss: 0.0616, Val acc1 : 0.4053
# EPOCH  64
# Train : Loss: 0.0193, Train acc1 : 0.7643
# Val : Loss: 0.0620, Val acc1 : 0.4158
# EPOCH  65
# Train : Loss: 0.0189, Train acc1 : 0.7742
# Val : Loss: 0.0623, Val acc1 : 0.4211
# EPOCH  66
# Train : Loss: 0.0193, Train acc1 : 0.7620
# Val : Loss: 0.0630, Val acc1 : 0.4105
# EPOCH  67
# Train : Loss: 0.0183, Train acc1 : 0.7696
# Val : Loss: 0.0646, Val acc1 : 0.4053
# EPOCH  68
# Train : Loss: 0.0188, Train acc1 : 0.7628
# Val : Loss: 0.0606, Val acc1 : 0.4263
# EPOCH  69
# Train : Loss: 0.0178, Train acc1 : 0.7841
# Val : Loss: 0.0622, Val acc1 : 0.4053
# EPOCH  70
# Train : Loss: 0.0187, Train acc1 : 0.7735
# Val : Loss: 0.0634, Val acc1 : 0.4158
# EPOCH  71
# Train : Loss: 0.0175, Train acc1 : 0.7887
# Val : Loss: 0.0616, Val acc1 : 0.4105
# EPOCH  72
# Train : Loss: 0.0186, Train acc1 : 0.7750
# Val : Loss: 0.0627, Val acc1 : 0.4211
# EPOCH  73
# Train : Loss: 0.0189, Train acc1 : 0.7818
# Val : Loss: 0.0680, Val acc1 : 0.4000
# EPOCH  74
# Train : Loss: 0.0180, Train acc1 : 0.7696
# Val : Loss: 0.0679, Val acc1 : 0.4000
# EPOCH  75
# Train : Loss: 0.0166, Train acc1 : 0.7918
# Val : Loss: 0.0671, Val acc1 : 0.4000
# EPOCH  76
# Train : Loss: 0.0173, Train acc1 : 0.7834
# Val : Loss: 0.0646, Val acc1 : 0.4368
# EPOCH  77
# Train : Loss: 0.0162, Train acc1 : 0.8063
# Val : Loss: 0.0655, Val acc1 : 0.4211
# EPOCH  78
# Train : Loss: 0.0169, Train acc1 : 0.7918
# Val : Loss: 0.0692, Val acc1 : 0.4053
# EPOCH  79
# Train : Loss: 0.0166, Train acc1 : 0.7948
# Val : Loss: 0.0660, Val acc1 : 0.4316
# EPOCH  80
# Train : Loss: 0.0163, Train acc1 : 0.8017
# Val : Loss: 0.0707, Val acc1 : 0.3842
# EPOCH  81
# Train : Loss: 0.0157, Train acc1 : 0.8055
# Val : Loss: 0.0687, Val acc1 : 0.4158
# EPOCH  82
# Train : Loss: 0.0169, Train acc1 : 0.7895
# Val : Loss: 0.0652, Val acc1 : 0.4158
# EPOCH  83
# Train : Loss: 0.0150, Train acc1 : 0.8185
# Val : Loss: 0.0681, Val acc1 : 0.3895
# EPOCH  84
# Train : Loss: 0.0156, Train acc1 : 0.8124
# Val : Loss: 0.0720, Val acc1 : 0.4105
# EPOCH  85
# Train : Loss: 0.0149, Train acc1 : 0.8085
# Val : Loss: 0.0699, Val acc1 : 0.4368
# EPOCH  86
# Train : Loss: 0.0152, Train acc1 : 0.8185
# Val : Loss: 0.0665, Val acc1 : 0.4474
# Best validation accuracy1  0.4473684210526316
# EPOCH  87
# Train : Loss: 0.0143, Train acc1 : 0.8291
# Val : Loss: 0.0678, Val acc1 : 0.4211
# EPOCH  88
# Train : Loss: 0.0147, Train acc1 : 0.8131
# Val : Loss: 0.0702, Val acc1 : 0.4053
# EPOCH  89
# Train : Loss: 0.0136, Train acc1 : 0.8284
# Val : Loss: 0.0710, Val acc1 : 0.4158
# EPOCH  90
# Train : Loss: 0.0151, Train acc1 : 0.8185
# Val : Loss: 0.0674, Val acc1 : 0.4368
# EPOCH  91
# Train : Loss: 0.0132, Train acc1 : 0.8352
# Val : Loss: 0.0687, Val acc1 : 0.4368
# EPOCH  92
# Train : Loss: 0.0146, Train acc1 : 0.8223
# Val : Loss: 0.0667, Val acc1 : 0.4474
# Best validation accuracy1  0.4473684210526316
# EPOCH  93
# Train : Loss: 0.0127, Train acc1 : 0.8413
# Val : Loss: 0.0698, Val acc1 : 0.4474
# Best validation accuracy1  0.4473684210526316
# EPOCH  94
# Train : Loss: 0.0135, Train acc1 : 0.8299
# Val : Loss: 0.0701, Val acc1 : 0.4526
# Best validation accuracy1  0.45263157894736844
# EPOCH  95
# Train : Loss: 0.0129, Train acc1 : 0.8429
# Val : Loss: 0.0712, Val acc1 : 0.4579
# Best validation accuracy1  0.45789473684210524
# EPOCH  96
# Train : Loss: 0.0129, Train acc1 : 0.8284
# Val : Loss: 0.0673, Val acc1 : 0.4632
# Best validation accuracy1  0.4631578947368421
# EPOCH  97
# Train : Loss: 0.0116, Train acc1 : 0.8528
# Val : Loss: 0.0697, Val acc1 : 0.4526
# EPOCH  98
# Train : Loss: 0.0123, Train acc1 : 0.8429
# Val : Loss: 0.0759, Val acc1 : 0.4316
# EPOCH  99
# Train : Loss: 0.0112, Train acc1 : 0.8497
# Val : Loss: 0.0730, Val acc1 : 0.4316
# EPOCH  100
# Train : Loss: 0.0119, Train acc1 : 0.8413
# Val : Loss: 0.0715, Val acc1 : 0.4684
# Best validation accuracy1  0.46842105263157896
# EPOCH  101
# Train : Loss: 0.0110, Train acc1 : 0.8619
# Val : Loss: 0.0753, Val acc1 : 0.4211
# EPOCH  102
# Train : Loss: 0.0122, Train acc1 : 0.8345
# Val : Loss: 0.0772, Val acc1 : 0.4368
# EPOCH  103
# Train : Loss: 0.0117, Train acc1 : 0.8497
# Val : Loss: 0.0767, Val acc1 : 0.4368
# EPOCH  104
# Train : Loss: 0.0136, Train acc1 : 0.8177
# Val : Loss: 0.0723, Val acc1 : 0.4526
# EPOCH  105
# Train : Loss: 0.0107, Train acc1 : 0.8596
# Val : Loss: 0.0742, Val acc1 : 0.4632
# EPOCH  106
# Train : Loss: 0.0111, Train acc1 : 0.8528
# Val : Loss: 0.0750, Val acc1 : 0.4474
# EPOCH  107
# Train : Loss: 0.0102, Train acc1 : 0.8596
# Val : Loss: 0.0770, Val acc1 : 0.4526
# EPOCH  108
# Train : Loss: 0.0104, Train acc1 : 0.8566
# Val : Loss: 0.0720, Val acc1 : 0.4474
# EPOCH  109
# Train : Loss: 0.0095, Train acc1 : 0.8696
# Val : Loss: 0.0761, Val acc1 : 0.4474
# EPOCH  110
# Train : Loss: 0.0098, Train acc1 : 0.8612
# Val : Loss: 0.0783, Val acc1 : 0.4368
# EPOCH  111
# Train : Loss: 0.0093, Train acc1 : 0.8688
# Val : Loss: 0.0791, Val acc1 : 0.4579
# EPOCH  112
# Train : Loss: 0.0113, Train acc1 : 0.8383
# Val : Loss: 0.0794, Val acc1 : 0.4789
# Best validation accuracy1  0.4789473684210526
# EPOCH  113
# Train : Loss: 0.0090, Train acc1 : 0.8734
# Val : Loss: 0.0774, Val acc1 : 0.4684
# EPOCH  114
# Train : Loss: 0.0094, Train acc1 : 0.8688
# Val : Loss: 0.0786, Val acc1 : 0.4684
# EPOCH  115
# Train : Loss: 0.0095, Train acc1 : 0.8818
# Val : Loss: 0.0785, Val acc1 : 0.4526
# EPOCH  116
# Train : Loss: 0.0114, Train acc1 : 0.8398
# Val : Loss: 0.0803, Val acc1 : 0.4579
# EPOCH  117
# Train : Loss: 0.0085, Train acc1 : 0.8795
# Val : Loss: 0.0781, Val acc1 : 0.4632
# EPOCH  118
# Train : Loss: 0.0093, Train acc1 : 0.8726
# Val : Loss: 0.0785, Val acc1 : 0.4579
# EPOCH  119
# Train : Loss: 0.0086, Train acc1 : 0.8688
# Val : Loss: 0.0797, Val acc1 : 0.4684
# EPOCH  120
# Train : Loss: 0.0084, Train acc1 : 0.8741
# Val : Loss: 0.0855, Val acc1 : 0.4474
# EPOCH  121
# Train : Loss: 0.0076, Train acc1 : 0.8772
# Val : Loss: 0.0809, Val acc1 : 0.4526
# EPOCH  122
# Train : Loss: 0.0079, Train acc1 : 0.8780
# Val : Loss: 0.0892, Val acc1 : 0.4579
# EPOCH  123
# Train : Loss: 0.0075, Train acc1 : 0.8818
# Val : Loss: 0.0818, Val acc1 : 0.4632
# EPOCH  124
# Train : Loss: 0.0083, Train acc1 : 0.8711
# Val : Loss: 0.0866, Val acc1 : 0.4579
# EPOCH  125
# Train : Loss: 0.0067, Train acc1 : 0.8886
# Val : Loss: 0.0864, Val acc1 : 0.4737
# EPOCH  126
# Train : Loss: 0.0079, Train acc1 : 0.8741
# Val : Loss: 0.0863, Val acc1 : 0.4526
# EPOCH  127
# Train : Loss: 0.0067, Train acc1 : 0.8825
# Val : Loss: 0.0866, Val acc1 : 0.4684
# EPOCH  128
# Train : Loss: 0.0067, Train acc1 : 0.8841
# Val : Loss: 0.0879, Val acc1 : 0.4579
# EPOCH  129
# Train : Loss: 0.0060, Train acc1 : 0.8909
# Val : Loss: 0.0873, Val acc1 : 0.4526
# EPOCH  130
# Train : Loss: 0.0067, Train acc1 : 0.8841
# Val : Loss: 0.0839, Val acc1 : 0.4684
# EPOCH  131
# Train : Loss: 0.0057, Train acc1 : 0.8986
# Val : Loss: 0.0908, Val acc1 : 0.4684
# EPOCH  132
# Train : Loss: 0.0077, Train acc1 : 0.8711
# Val : Loss: 0.0861, Val acc1 : 0.4579
# EPOCH  133
# Train : Loss: 0.0058, Train acc1 : 0.8947
# Val : Loss: 0.0863, Val acc1 : 0.4579
# EPOCH  134
# Train : Loss: 0.0063, Train acc1 : 0.8886
# Val : Loss: 0.0849, Val acc1 : 0.4789
# Best validation accuracy1  0.4789473684210526
# EPOCH  135
# Train : Loss: 0.0053, Train acc1 : 0.9008
# Val : Loss: 0.0924, Val acc1 : 0.4632
# EPOCH  136
# Train : Loss: 0.0060, Train acc1 : 0.8940
# Val : Loss: 0.0897, Val acc1 : 0.4684
# EPOCH  137
# Train : Loss: 0.0069, Train acc1 : 0.8856
# Val : Loss: 0.0809, Val acc1 : 0.4737
# EPOCH  138
# Train : Loss: 0.0058, Train acc1 : 0.8924
# Val : Loss: 0.0905, Val acc1 : 0.4579
# EPOCH  139
# Train : Loss: 0.0047, Train acc1 : 0.9024
# Val : Loss: 0.0942, Val acc1 : 0.4632
# EPOCH  140
# Train : Loss: 0.0061, Train acc1 : 0.8932
# Val : Loss: 0.0943, Val acc1 : 0.4526
# EPOCH  141
# Train : Loss: 0.0049, Train acc1 : 0.9008
# Val : Loss: 0.0963, Val acc1 : 0.4684
# EPOCH  142
# Train : Loss: 0.0054, Train acc1 : 0.9001
# Val : Loss: 0.0924, Val acc1 : 0.4684
# EPOCH  143
# Train : Loss: 0.0042, Train acc1 : 0.9077
# Val : Loss: 0.0929, Val acc1 : 0.4684
# EPOCH  144
# Train : Loss: 0.0046, Train acc1 : 0.9016
# Val : Loss: 0.0939, Val acc1 : 0.4737
# EPOCH  145
# Train : Loss: 0.0042, Train acc1 : 0.9031
# Val : Loss: 0.0935, Val acc1 : 0.4526
# EPOCH  146
# Train : Loss: 0.0042, Train acc1 : 0.9039
# Val : Loss: 0.0988, Val acc1 : 0.4737
# EPOCH  147
# Train : Loss: 0.0037, Train acc1 : 0.9085
# Val : Loss: 0.1003, Val acc1 : 0.4789
# Best validation accuracy1  0.4789473684210526
# EPOCH  148
# Train : Loss: 0.0047, Train acc1 : 0.8955
# Val : Loss: 0.0928, Val acc1 : 0.4684
# EPOCH  149
# Train : Loss: 0.0040, Train acc1 : 0.9024
# Val : Loss: 0.0982, Val acc1 : 0.4368
# EPOCH  150
# Train : Loss: 0.0038, Train acc1 : 0.9001
# Val : Loss: 0.0960, Val acc1 : 0.4632
# EPOCH  151
# Train : Loss: 0.0033, Train acc1 : 0.9100
# Val : Loss: 0.1002, Val acc1 : 0.4632
# EPOCH  152
# Train : Loss: 0.0035, Train acc1 : 0.9077
# Val : Loss: 0.1049, Val acc1 : 0.4526
# EPOCH  153
# Train : Loss: 0.0040, Train acc1 : 0.9039
# Val : Loss: 0.0966, Val acc1 : 0.4526
# EPOCH  154
# Train : Loss: 0.0041, Train acc1 : 0.9024
# Val : Loss: 0.0948, Val acc1 : 0.4789
# Best validation accuracy1  0.4789473684210526
# EPOCH  155
# Train : Loss: 0.0031, Train acc1 : 0.9153
# Val : Loss: 0.0979, Val acc1 : 0.4737
# EPOCH  156
# Train : Loss: 0.0032, Train acc1 : 0.9138
# Val : Loss: 0.1008, Val acc1 : 0.4789
# Best validation accuracy1  0.4789473684210526
# EPOCH  157
# Train : Loss: 0.0028, Train acc1 : 0.9153
# Val : Loss: 0.1015, Val acc1 : 0.4842
# Best validation accuracy1  0.4842105263157895
# EPOCH  158
# Train : Loss: 0.0030, Train acc1 : 0.9153
# Val : Loss: 0.1037, Val acc1 : 0.4632
# EPOCH  159
# Train : Loss: 0.0029, Train acc1 : 0.9146
# Val : Loss: 0.1029, Val acc1 : 0.4579
# EPOCH  160
# Train : Loss: 0.0039, Train acc1 : 0.9062
# Val : Loss: 0.1106, Val acc1 : 0.4789
# EPOCH  161
# Train : Loss: 0.0063, Train acc1 : 0.8909
# Val : Loss: 0.1073, Val acc1 : 0.4579
# EPOCH  162
# Train : Loss: 0.0031, Train acc1 : 0.9092
# Val : Loss: 0.1067, Val acc1 : 0.4842
# Best validation accuracy1  0.4842105263157895
# EPOCH  163
# Train : Loss: 0.0027, Train acc1 : 0.9169
# Val : Loss: 0.1048, Val acc1 : 0.4684
# EPOCH  164
# Train : Loss: 0.0030, Train acc1 : 0.9123
# Val : Loss: 0.1073, Val acc1 : 0.4684
# EPOCH  165
# Train : Loss: 0.0026, Train acc1 : 0.9146
# Val : Loss: 0.1070, Val acc1 : 0.4789
# EPOCH  166
# Train : Loss: 0.0024, Train acc1 : 0.9169
# Val : Loss: 0.1065, Val acc1 : 0.4684
# EPOCH  167
# Train : Loss: 0.0021, Train acc1 : 0.9161
# Val : Loss: 0.1120, Val acc1 : 0.4737
# EPOCH  168
# Train : Loss: 0.0024, Train acc1 : 0.9169
# Val : Loss: 0.1110, Val acc1 : 0.4737
# EPOCH  169
# Train : Loss: 0.0021, Train acc1 : 0.9199
# Val : Loss: 0.1074, Val acc1 : 0.4842
# Best validation accuracy1  0.4842105263157895
# EPOCH  170
# Train : Loss: 0.0027, Train acc1 : 0.9146
# Val : Loss: 0.0995, Val acc1 : 0.5158
# Best validation accuracy1  0.5157894736842106
# EPOCH  171
# Train : Loss: 0.0027, Train acc1 : 0.9207
# Val : Loss: 0.1127, Val acc1 : 0.4737
# EPOCH  172
# Train : Loss: 0.0084, Train acc1 : 0.8696
# Val : Loss: 0.1027, Val acc1 : 0.4789
# EPOCH  173
# Train : Loss: 0.0033, Train acc1 : 0.9115
# Val : Loss: 0.1041, Val acc1 : 0.4632
# EPOCH  174
# Train : Loss: 0.0024, Train acc1 : 0.9169
# Val : Loss: 0.1078, Val acc1 : 0.4842
# EPOCH  175
# Train : Loss: 0.0020, Train acc1 : 0.9207
# Val : Loss: 0.1084, Val acc1 : 0.4789
# EPOCH  176
# Train : Loss: 0.0019, Train acc1 : 0.9199
# Val : Loss: 0.1102, Val acc1 : 0.4789
# EPOCH  177
# Train : Loss: 0.0017, Train acc1 : 0.9214
# Val : Loss: 0.1082, Val acc1 : 0.4842
# EPOCH  178
# Train : Loss: 0.0025, Train acc1 : 0.9146
# Val : Loss: 0.1159, Val acc1 : 0.4684
# EPOCH  179
# Train : Loss: 0.0020, Train acc1 : 0.9199
# Val : Loss: 0.1136, Val acc1 : 0.4789
# EPOCH  180
# Train : Loss: 0.0018, Train acc1 : 0.9207
# Val : Loss: 0.1134, Val acc1 : 0.4789
# EPOCH  181
# Train : Loss: 0.0015, Train acc1 : 0.9199
# Val : Loss: 0.1134, Val acc1 : 0.4947
# EPOCH  182
# Train : Loss: 0.0015, Train acc1 : 0.9245
# Val : Loss: 0.1131, Val acc1 : 0.4895
# EPOCH  183
# Train : Loss: 0.0015, Train acc1 : 0.9245
# Val : Loss: 0.1150, Val acc1 : 0.4842
# EPOCH  184
# Train : Loss: 0.0015, Train acc1 : 0.9222
# Val : Loss: 0.1220, Val acc1 : 0.4789
# EPOCH  185
# Train : Loss: 0.0017, Train acc1 : 0.9184
# Val : Loss: 0.1136, Val acc1 : 0.4789
# EPOCH  186
# Train : Loss: 0.0013, Train acc1 : 0.9222
# Val : Loss: 0.1216, Val acc1 : 0.5000
# EPOCH  187
# Train : Loss: 0.0012, Train acc1 : 0.9260
# Val : Loss: 0.1193, Val acc1 : 0.4947
# EPOCH  188
# Train : Loss: 0.0013, Train acc1 : 0.9252
# Val : Loss: 0.1230, Val acc1 : 0.4947
# EPOCH  189
# Train : Loss: 0.0011, Train acc1 : 0.9252
# Val : Loss: 0.1256, Val acc1 : 0.4947
# EPOCH  190
# Train : Loss: 0.0012, Train acc1 : 0.9260
# Val : Loss: 0.1253, Val acc1 : 0.5000
# EPOCH  191
# Train : Loss: 0.0010, Train acc1 : 0.9268
# Val : Loss: 0.1249, Val acc1 : 0.4895
# EPOCH  192
# Train : Loss: 0.0010, Train acc1 : 0.9252
# Val : Loss: 0.1285, Val acc1 : 0.4842
# EPOCH  193
# Train : Loss: 0.0010, Train acc1 : 0.9252
# Val : Loss: 0.1279, Val acc1 : 0.4789
# EPOCH  194
# Train : Loss: 0.0070, Train acc1 : 0.8833
# Val : Loss: 0.1068, Val acc1 : 0.4842
# EPOCH  195
# Train : Loss: 0.0035, Train acc1 : 0.9092
# Val : Loss: 0.1137, Val acc1 : 0.4684
# EPOCH  196
# Train : Loss: 0.0020, Train acc1 : 0.9191
# Val : Loss: 0.1192, Val acc1 : 0.4684
# EPOCH  197
# Train : Loss: 0.0012, Train acc1 : 0.9222
# Val : Loss: 0.1211, Val acc1 : 0.4632
# EPOCH  198
# Train : Loss: 0.0012, Train acc1 : 0.9214
# Val : Loss: 0.1290, Val acc1 : 0.4842
# EPOCH  199
# Train : Loss: 0.0010, Train acc1 : 0.9245
# Val : Loss: 0.1205, Val acc1 : 0.4737
# EPOCH  200
# Train : Loss: 0.0010, Train acc1 : 0.9230
# Val : Loss: 0.1223, Val acc1 : 0.4684

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score

modeltest=Classifier()
modeltest.load_state_dict(best_state)
modeltest.cuda()
modeltest.eval()
truth=[]
preds=[]
for minibatch in test_data_loader:
            X_test, Y1_test  = minibatch
            X_test=X_test.cuda()
            Y1_test=Y1_test.cuda()
            output_test = modeltest(X_test.float())
            output_test=output_test.squeeze(1)
            prediction = torch.ge(output_test, 0.5).float()
            truth.extend(Y1_test.tolist())
            preds.extend(prediction.tolist())
acc=accuracy_score(truth,preds)
# print(truth,preds)
tn, fp, fn, tp = confusion_matrix(truth, preds).ravel()
f1score=f1_score(truth, preds)
precision=precision_score(truth, preds)
recall=recall_score(truth,preds)
roc=roc_auc_score(truth,preds)
specificity=tn/(tn+fp)

print('{:.2f} {:.2f} {:.2f} {:.2f} {:.2f} {:.2f}'.format(acc,f1score,precision,recall,roc,specificity))
# Out:
# 0.42 0.41 0.38 0.46 0.42 0.39

# %%
for i in range(len(modelname)):
    modeltest=Classifier()
    modeltest.load_state_dict(best_state)
    modeltest.cuda()
    modeltest.eval()
    truth=[]
    preds=[]
    for minibatch in test_data_loader:
                X_test, Y1_test  = minibatch
                X_test=X_test.cuda()
                Y1_test=Y1_test.cuda()
                output_test = modeltest(X_test.float())
                output_test=output_test.squeeze(1)
                prediction = torch.ge(output_test, 0.5).float()
                truth.extend(Y1_test.tolist())
                preds.extend(prediction.tolist())
    acc=accuracy_score(truth,preds)
    # print(truth,preds)
    tn, fp, fn, tp = confusion_matrix(truth, preds).ravel()
    f1score=f1_score(truth, preds)
    precision=precision_score(truth, preds)
    recall=recall_score(truth,preds)
    roc=roc_auc_score(truth,preds)
    specificity=tn/(tn+fp)

    print('{:.2f} {:.2f} {:.2f} {:.2f} {:.2f} {:.2f}'.format(acc,f1score,precision,recall,roc,specificity))
