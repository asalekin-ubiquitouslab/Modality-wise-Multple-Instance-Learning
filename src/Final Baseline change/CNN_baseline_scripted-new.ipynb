# %%
import math
import pylab
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import numpy as np
from torch.utils import data
import argparse
import torch
import torch.utils.data as data_utils
import torch.optim as optim
from torch.autograd import Variable
import torch
import torch.nn as nn
import torch.nn.functional as F

seed = 2021
torch.manual_seed(seed)
torch.cuda.manual_seed(0)
np.random.seed(seed)


def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    numpy.random.seed(worker_seed)
    random.seed(worker_seed)
torch.backends.cudnn.deterministic = True


class Dataset(data.Dataset):
    def __init__(self, X1, Y1):
        self.X1 = X1
        self.Y1 = Y1

    def __len__(self):
        return len(self.X1)

    def __getitem__(self, index):
        x = self.X1[index]
        y1 = self.Y1[index]
        return x, y1

# %%
from collections import OrderedDict
def init_weights(m):
    if type(m) == nn.Linear:
        torch.nn.init.xavier_uniform_(m.weight)
        m.bias.data.fill_(0.01)
    if type(m) == nn.Conv2d:
        torch.nn.init.xavier_uniform_(m.weight)
        m.bias.data.fill_(0.01)

class Classifier(nn.Module):
    def __init__(self):
        super(Classifier, self).__init__()
        self.L = 128
        self.D = 64
        self.K = 1
        self.feature_size = 24
        self.shared_layer_size = 128

        self.fc = nn.Sequential(
            nn.Conv1d(1, 64, kernel_size=(1,2)),
            nn.ReLU(),
            nn.Conv1d(64,64, kernel_size=(1,2)),
            nn.ReLU(),
            nn.Conv1d(64,64, kernel_size=(1,2)),
            nn.ReLU()
          )
        self.fc2 = nn.Sequential(
            nn.Linear(6080, 1024),
            nn.BatchNorm1d(1024,affine=False),
            nn.ReLU(),
            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Linear(256, 1),
            nn.Sigmoid()
        )


    def forward(self, x):
        
        Y_prob=self.fc(x)
        Y_prob=self.fc2(Y_prob.reshape(Y_prob.size(0),-1))
        
        return Y_prob

# %%
from torch.optim.lr_scheduler import _LRScheduler
class CyclicLR(_LRScheduler):
    
    def __init__(self, optimizer, schedule, last_epoch=-1):
        assert callable(schedule)
        self.schedule = schedule
        super().__init__(optimizer, last_epoch)

    def get_lr(self):
        return [self.schedule(self.last_epoch, lr) for lr in self.base_lrs]

# %%
def cosine(t_max, eta_min=0):
    
    def scheduler(epoch, base_lr):
        t = epoch % t_max
        return eta_min + (base_lr - eta_min)*(1 + np.cos(np.pi*t/t_max))/2
    
    return scheduler

# %%
xTrain=np.load("../extracted_features/Change/input_features_train_grp3.npy")
labels_stress_train=np.load("../extracted_features/Change/labels_stress_train_grp3.npy")
yTrain=np.load("../extracted_features/Change/labels_train_grp3.npy")

xTest=np.load("../extracted_features/Change/input_features_test_grp3.npy")
labels_stress_test=np.load("../extracted_features/Change/labels_stress_test_grp3.npy")
yTest=np.load("../extracted_features/Change/labels_test_grp3.npy")


xVal=np.load("../extracted_features/Change/input_features_val_grp3.npy")
labels_stress_val=np.load("../extracted_features/Change/labels_stress_val_grp3.npy")
yVal=np.load("../extracted_features/Change/labels_val_grp3.npy")


# train_features=np.load("../extracted_features/bl/0/GRP-3/input_features_train_grp3.npy")
# labels_train=np.load("../extracted_features/bl/0/GRP-3/labels_train_grp3.npy")

# test_features=np.load("../extracted_features/bl/0/GRP-3/input_features_test_grp3.npy")
# labels_test=np.load("../extracted_features/bl/0/GRP-3/labels_test_grp3.npy")

# val_features=np.load("../extracted_features/bl/0/GRP-3/input_features_val_grp3.npy")
# labels_val=np.load("../extracted_features/bl/0/GRP-3/labels_val_grp3.npy")

# %%
# print(labels_train.shape,labels_train)

# %%
print(xTrain.shape,yTrain.shape)
print(xTest.shape,yTest.shape)
print(xVal.shape,yVal.shape)
# Out:
# (512, 19, 8) (512,)
# (122, 19, 8) (122,)
# (118, 19, 8) (118,)

# %%
# print(train_features.shape,labels_train.shape)
# print(test_features.shape,labels_test.shape)
# print(val_features.shape,labels_val.shape)

# %%
# train_features=train_features.reshape(len(train_features),1,19,24)
# test_features=test_features.reshape(len(test_features),1,19,24)
# val_features=val_features.reshape(len(val_features),1,19,24)

xTrain = xTrain.reshape(len(xTrain),1,19,8)
xTest = xTest.reshape(len(xTest),1,19,8)
xVal = xVal.reshape(len(xVal),1,19,8)

# %%
# xTrain=np.append(train_features,xTrain,axis=0)
# xTest=np.append(test_features,xTest,axis=0)
# xVal=np.append(val_features,xVal,axis=0)
# yTrain=np.append(labels_train,yTrain,axis=0)
# yTest=np.append(labels_test,yTest,axis=0)
# yVal=np.append(labels_val,yVal,axis=0)

# %%
import os
def readFeatures(path):
    features=np.array([])
    start=0
    for file in os.listdir(path):
        d = os.path.join(path, file)
        datafile=d+"/features.npy"
        try:
            temp=np.load(datafile)
#             print(datafile)
#             print(temp.shape)
            if(start==0):
                features=temp
                if(d[-10]=='S'):
                    label=np.ones(len(temp))
                else:
                    label=np.zeros(len(temp))
                start=1
            else:
                features=np.vstack((features,temp))
                if(d[-10]=='S'):
                    label=np.append(label,np.ones(len(temp)))
                else:
                    label=np.append(label,np.zeros(len(temp)))
        except IOError:
            print('file not in Scripted')

            
    return features,label

def load_data(path,mode):
    if mode == "test":
        xTest,yTest=readFeatures(path+"/"+mode)
        xTest = xTest.reshape(len(xTest),1,19,8)
        return Dataset(xTest,yTest)
        
    elif mode == "train":
        xTrain,yTrain=readFeatures(path+"/"+mode)
        xTrain = xTrain.reshape(len(xTrain),1,19,8)
        return Dataset(xTrain,yTrain)
        
    elif mode == "val":
        xVal,yVal=readFeatures(path+"/"+mode)
        xVal = xVal.reshape(len(xVal),1,19,8)
        return Dataset(xVal,yVal)
    else:
        print("Mode not defined")
        return

train_data = load_data("../Participant_wise_physio_change",'train')
test_data = load_data("../Participant_wise_physio_change",'test')
val_data = load_data("../Participant_wise_physio_change",'val')

# %%
batch_size=20

# train_data = Dataset(xTrain, yTrain)
# test_data=Dataset(xTest,yTest)
# val_data=Dataset(xVal,yVal)

# train_data = Dataset(train_features, labels_train)
# test_data=Dataset(test_features,labels_test)
# val_data=Dataset(val_features,labels_val)

train_data_loader = DataLoader(train_data,worker_init_fn=seed_worker, shuffle=True, batch_size=batch_size)
val_data_loader=DataLoader(val_data,worker_init_fn=seed_worker,shuffle=True,batch_size=batch_size)
test_data_loader=DataLoader(test_data,worker_init_fn=seed_worker,shuffle=True,batch_size=batch_size)

# %%
for batch in val_data_loader:
    print(batch[1].shape)
    break
print(len(val_data_loader))
# Out:
# torch.Size([20])
# 6

# %%
feature_size = 8
shared_layer_size = 512
LR = 0.0001
epoch = 100
model=Classifier()
model.cuda()
iterations_per_epoch = len(train_data_loader)
model.apply(init_weights)
loss_func = nn.BCELoss()
optimizer = torch.optim.RMSprop(model.parameters(), lr=LR)
sched = CyclicLR(optimizer, cosine(t_max=iterations_per_epoch * 2, eta_min=LR/100))

# %%
# from torchsummary import summary
# summary(model.cuda(),(1,19,8))
# torch.save(model, "modelarchitect_final.pt")

# %%
from sklearn.metrics import accuracy_score
best_acc1 = 0
modelname=[]
truth=[]
preds=[]

for it in range(epoch+1):
    model.train()
    total=len(train_data_loader)*batch_size
    train_loss = 0.
    for minibatch in train_data_loader:
        X, Y1  = minibatch
        X=X.cuda()
        Y1=Y1.cuda()
        output = model(X.float())
        output=output.squeeze(1)
        loss = loss_func(output, Y1.float())
        Y_hat1 = torch.ge(output, 0.5).float()
        train_loss += loss.item()
        truth.extend(Y1.tolist())
        preds.extend(Y_hat1.tolist())
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        sched.step()
    trainacc1=accuracy_score(truth,preds)
    train_loss /= total
    print("EPOCH ",it)
    print('Train : Loss: {:.4f}, Train acc1 : {:.4f}'.format(train_loss,trainacc1))
    
    count=0
    val_loss= 0.
    truth=[]
    preds=[]
    total=len(val_data_loader)*batch_size
    model.eval()    
    for minibatch in val_data_loader:
        X_valid, Y1_valid  = minibatch
        X_valid=X_valid.cuda()
        Y1_valid=Y1_valid.cuda()
        output_val = model(X_valid.float())
        output_val=output_val.squeeze(1)
        loss = loss_func(output_val, Y1_valid.float())
        Y_hat1_val = torch.ge(output_val, 0.5).float()
        val_loss += loss.item()
        truth.extend(Y1_valid.tolist())
        preds.extend(Y_hat1_val.tolist())
    valacc1=accuracy_score(truth,preds)
    val_loss /= total
    print('Val : Loss: {:.4f}, Val acc1 : {:.4f}'.format(val_loss,valacc1))
    if valacc1 >= best_acc1:
        best_acc1 = valacc1
        best_state = model.state_dict()
        print('Best validation accuracy1 ', best_acc1)
# Out:
# EPOCH  0
# Train : Loss: 0.0343, Train acc1 : 0.6124
# Val : Loss: 0.0584, Val acc1 : 0.3305
# Best validation accuracy1  0.3305084745762712
# EPOCH  1
# Train : Loss: 0.0252, Train acc1 : 0.6877
# Val : Loss: 0.0601, Val acc1 : 0.3729
# Best validation accuracy1  0.3728813559322034
# EPOCH  2
# Train : Loss: 0.0254, Train acc1 : 0.6814
# Val : Loss: 0.0766, Val acc1 : 0.4492
# Best validation accuracy1  0.4491525423728814
# EPOCH  3
# Train : Loss: 0.0221, Train acc1 : 0.7397
# Val : Loss: 0.0597, Val acc1 : 0.4068
# EPOCH  4
# Train : Loss: 0.0216, Train acc1 : 0.7397
# Val : Loss: 0.0617, Val acc1 : 0.3644
# EPOCH  5
# Train : Loss: 0.0185, Train acc1 : 0.7650
# Val : Loss: 0.0648, Val acc1 : 0.3729
# EPOCH  6
# Train : Loss: 0.0193, Train acc1 : 0.7508
# Val : Loss: 0.0815, Val acc1 : 0.4153
# EPOCH  7
# Train : Loss: 0.0149, Train acc1 : 0.8202
# Val : Loss: 0.0695, Val acc1 : 0.3559
# EPOCH  8
# Train : Loss: 0.0154, Train acc1 : 0.7934
# Val : Loss: 0.0854, Val acc1 : 0.4407
# EPOCH  9
# Train : Loss: 0.0138, Train acc1 : 0.8107
# Val : Loss: 0.0742, Val acc1 : 0.4237
# EPOCH  10
# Train : Loss: 0.0144, Train acc1 : 0.8044
# Val : Loss: 0.0661, Val acc1 : 0.3983
# EPOCH  11
# Train : Loss: 0.0115, Train acc1 : 0.8202
# Val : Loss: 0.0657, Val acc1 : 0.4407
# EPOCH  12
# Train : Loss: 0.0124, Train acc1 : 0.8265
# Val : Loss: 0.0730, Val acc1 : 0.4576
# Best validation accuracy1  0.4576271186440678
# EPOCH  13
# Train : Loss: 0.0093, Train acc1 : 0.8596
# Val : Loss: 0.0667, Val acc1 : 0.4831
# Best validation accuracy1  0.4830508474576271
# EPOCH  14
# Train : Loss: 0.0098, Train acc1 : 0.8565
# Val : Loss: 0.1030, Val acc1 : 0.3729
# EPOCH  15
# Train : Loss: 0.0078, Train acc1 : 0.8580
# Val : Loss: 0.0772, Val acc1 : 0.4237
# EPOCH  16
# Train : Loss: 0.0083, Train acc1 : 0.8628
# Val : Loss: 0.0661, Val acc1 : 0.4153
# EPOCH  17
# Train : Loss: 0.0060, Train acc1 : 0.8675
# Val : Loss: 0.0746, Val acc1 : 0.4576
# EPOCH  18
# Train : Loss: 0.0079, Train acc1 : 0.8628
# Val : Loss: 0.0927, Val acc1 : 0.4661
# EPOCH  19
# Train : Loss: 0.0048, Train acc1 : 0.8849
# Val : Loss: 0.0806, Val acc1 : 0.4746
# EPOCH  20
# Train : Loss: 0.0074, Train acc1 : 0.8659
# Val : Loss: 0.1019, Val acc1 : 0.4237
# EPOCH  21
# Train : Loss: 0.0041, Train acc1 : 0.8833
# Val : Loss: 0.1008, Val acc1 : 0.4492
# EPOCH  22
# Train : Loss: 0.0054, Train acc1 : 0.8628
# Val : Loss: 0.1121, Val acc1 : 0.4576
# EPOCH  23
# Train : Loss: 0.0041, Train acc1 : 0.8833
# Val : Loss: 0.0966, Val acc1 : 0.4407
# EPOCH  24
# Train : Loss: 0.0054, Train acc1 : 0.8722
# Val : Loss: 0.1545, Val acc1 : 0.4407
# EPOCH  25
# Train : Loss: 0.0031, Train acc1 : 0.8927
# Val : Loss: 0.1294, Val acc1 : 0.4576
# EPOCH  26
# Train : Loss: 0.0032, Train acc1 : 0.8896
# Val : Loss: 0.1249, Val acc1 : 0.4407
# EPOCH  27
# Train : Loss: 0.0019, Train acc1 : 0.8927
# Val : Loss: 0.0907, Val acc1 : 0.4322
# EPOCH  28
# Train : Loss: 0.0032, Train acc1 : 0.8833
# Val : Loss: 0.1601, Val acc1 : 0.4492
# EPOCH  29
# Train : Loss: 0.0024, Train acc1 : 0.8896
# Val : Loss: 0.1174, Val acc1 : 0.4492
# EPOCH  30
# Train : Loss: 0.0020, Train acc1 : 0.8912
# Val : Loss: 0.1238, Val acc1 : 0.4492
# EPOCH  31
# Train : Loss: 0.0013, Train acc1 : 0.8959
# Val : Loss: 0.1115, Val acc1 : 0.4068
# EPOCH  32
# Train : Loss: 0.0021, Train acc1 : 0.8864
# Val : Loss: 0.1222, Val acc1 : 0.4322
# EPOCH  33
# Train : Loss: 0.0014, Train acc1 : 0.8912
# Val : Loss: 0.1050, Val acc1 : 0.4407
# EPOCH  34
# Train : Loss: 0.0020, Train acc1 : 0.8864
# Val : Loss: 0.1146, Val acc1 : 0.4915
# Best validation accuracy1  0.4915254237288136
# EPOCH  35
# Train : Loss: 0.0013, Train acc1 : 0.9038
# Val : Loss: 0.0933, Val acc1 : 0.4661
# EPOCH  36
# Train : Loss: 0.0015, Train acc1 : 0.8991
# Val : Loss: 0.1779, Val acc1 : 0.4661
# EPOCH  37
# Train : Loss: 0.0014, Train acc1 : 0.8959
# Val : Loss: 0.1361, Val acc1 : 0.4237
# EPOCH  38
# Train : Loss: 0.0023, Train acc1 : 0.8833
# Val : Loss: 0.1151, Val acc1 : 0.4915
# Best validation accuracy1  0.4915254237288136
# EPOCH  39
# Train : Loss: 0.0012, Train acc1 : 0.9006
# Val : Loss: 0.1297, Val acc1 : 0.4661
# EPOCH  40
# Train : Loss: 0.0012, Train acc1 : 0.8991
# Val : Loss: 0.1158, Val acc1 : 0.3559
# EPOCH  41
# Train : Loss: 0.0006, Train acc1 : 0.8801
# Val : Loss: 0.1492, Val acc1 : 0.4237
# EPOCH  42
# Train : Loss: 0.0010, Train acc1 : 0.8912
# Val : Loss: 0.2170, Val acc1 : 0.4407
# EPOCH  43
# Train : Loss: 0.0004, Train acc1 : 0.8959
# Val : Loss: 0.1855, Val acc1 : 0.4407
# EPOCH  44
# Train : Loss: 0.0007, Train acc1 : 0.8943
# Val : Loss: 0.1785, Val acc1 : 0.4661
# EPOCH  45
# Train : Loss: 0.0004, Train acc1 : 0.9006
# Val : Loss: 0.1370, Val acc1 : 0.4068
# EPOCH  46
# Train : Loss: 0.0063, Train acc1 : 0.8517
# Val : Loss: 0.1628, Val acc1 : 0.4322
# EPOCH  47
# Train : Loss: 0.0014, Train acc1 : 0.8927
# Val : Loss: 0.1473, Val acc1 : 0.4068
# EPOCH  48
# Train : Loss: 0.0008, Train acc1 : 0.8896
# Val : Loss: 0.1640, Val acc1 : 0.4661
# EPOCH  49
# Train : Loss: 0.0008, Train acc1 : 0.8991
# Val : Loss: 0.1528, Val acc1 : 0.4407
# EPOCH  50
# Train : Loss: 0.0008, Train acc1 : 0.8943
# Val : Loss: 0.0925, Val acc1 : 0.5424
# Best validation accuracy1  0.5423728813559322
# EPOCH  51
# Train : Loss: 0.0006, Train acc1 : 0.9148
# Val : Loss: 0.1149, Val acc1 : 0.4407
# EPOCH  52
# Train : Loss: 0.0006, Train acc1 : 0.8959
# Val : Loss: 0.1012, Val acc1 : 0.4492
# EPOCH  53
# Train : Loss: 0.0004, Train acc1 : 0.8975
# Val : Loss: 0.1155, Val acc1 : 0.3983
# EPOCH  54
# Train : Loss: 0.0006, Train acc1 : 0.8864
# Val : Loss: 0.1155, Val acc1 : 0.4322
# EPOCH  55
# Train : Loss: 0.0004, Train acc1 : 0.8943
# Val : Loss: 0.1267, Val acc1 : 0.4153
# EPOCH  56
# Train : Loss: 0.0009, Train acc1 : 0.8864
# Val : Loss: 0.1348, Val acc1 : 0.4492
# EPOCH  57
# Train : Loss: 0.0004, Train acc1 : 0.8975
# Val : Loss: 0.1349, Val acc1 : 0.4407
# EPOCH  58
# Train : Loss: 0.0005, Train acc1 : 0.8943
# Val : Loss: 0.1009, Val acc1 : 0.4746
# EPOCH  59
# Train : Loss: 0.0003, Train acc1 : 0.9022
# Val : Loss: 0.1330, Val acc1 : 0.4576
# EPOCH  60
# Train : Loss: 0.0002, Train acc1 : 0.8991
# Val : Loss: 0.1208, Val acc1 : 0.4576
# EPOCH  61
# Train : Loss: 0.0002, Train acc1 : 0.8991
# Val : Loss: 0.1223, Val acc1 : 0.4576
# EPOCH  62
# Train : Loss: 0.0001, Train acc1 : 0.8991
# Val : Loss: 0.1355, Val acc1 : 0.4576
# EPOCH  63
# Train : Loss: 0.0002, Train acc1 : 0.8991
# Val : Loss: 0.1341, Val acc1 : 0.4661
# EPOCH  64
# Train : Loss: 0.0099, Train acc1 : 0.8612
# Val : Loss: 0.2877, Val acc1 : 0.4661
# EPOCH  65
# Train : Loss: 0.0010, Train acc1 : 0.8959
# Val : Loss: 0.2143, Val acc1 : 0.4746
# EPOCH  66
# Train : Loss: 0.0007, Train acc1 : 0.9022
# Val : Loss: 0.1916, Val acc1 : 0.4407
# EPOCH  67
# Train : Loss: 0.0004, Train acc1 : 0.8943
# Val : Loss: 0.1674, Val acc1 : 0.4492
# EPOCH  68
# Train : Loss: 0.0007, Train acc1 : 0.8959
# Val : Loss: 0.1962, Val acc1 : 0.4492
# EPOCH  69
# Train : Loss: 0.0006, Train acc1 : 0.8943
# Val : Loss: 0.2015, Val acc1 : 0.4492
# EPOCH  70
# Train : Loss: 0.0003, Train acc1 : 0.8975
# Val : Loss: 0.2076, Val acc1 : 0.4407
# EPOCH  71
# Train : Loss: 0.0002, Train acc1 : 0.8959
# Val : Loss: 0.2045, Val acc1 : 0.4153
# EPOCH  72
# Train : Loss: 0.0003, Train acc1 : 0.8912
# Val : Loss: 0.1653, Val acc1 : 0.4492
# EPOCH  73
# Train : Loss: 0.0002, Train acc1 : 0.8975
# Val : Loss: 0.1809, Val acc1 : 0.4407
# EPOCH  74
# Train : Loss: 0.0002, Train acc1 : 0.8959
# Val : Loss: 0.1567, Val acc1 : 0.3983
# EPOCH  75
# Train : Loss: 0.0001, Train acc1 : 0.8880
# Val : Loss: 0.1744, Val acc1 : 0.4576
# EPOCH  76
# Train : Loss: 0.0002, Train acc1 : 0.8991
# Val : Loss: 0.2138, Val acc1 : 0.4407
# EPOCH  77
# Train : Loss: 0.0001, Train acc1 : 0.8959
# Val : Loss: 0.1823, Val acc1 : 0.4322
# EPOCH  78
# Train : Loss: 0.0004, Train acc1 : 0.8927
# Val : Loss: 0.1602, Val acc1 : 0.4237
# EPOCH  79
# Train : Loss: 0.0003, Train acc1 : 0.8912
# Val : Loss: 0.2046, Val acc1 : 0.4492
# EPOCH  80
# Train : Loss: 0.0001, Train acc1 : 0.8975
# Val : Loss: 0.1793, Val acc1 : 0.4068
# EPOCH  81
# Train : Loss: 0.0002, Train acc1 : 0.8896
# Val : Loss: 0.1874, Val acc1 : 0.4153
# EPOCH  82
# Train : Loss: 0.0001, Train acc1 : 0.8912
# Val : Loss: 0.1966, Val acc1 : 0.4492
# EPOCH  83
# Train : Loss: 0.0001, Train acc1 : 0.8975
# Val : Loss: 0.1897, Val acc1 : 0.4492
# EPOCH  84
# Train : Loss: 0.0001, Train acc1 : 0.8975
# Val : Loss: 0.1296, Val acc1 : 0.4915
# EPOCH  85
# Train : Loss: 0.0000, Train acc1 : 0.9054
# Val : Loss: 0.1297, Val acc1 : 0.5000
# EPOCH  86
# Train : Loss: 0.0012, Train acc1 : 0.8991
# Val : Loss: 0.1796, Val acc1 : 0.4322
# EPOCH  87
# Train : Loss: 0.0015, Train acc1 : 0.8833
# Val : Loss: 0.1848, Val acc1 : 0.3983
# EPOCH  88
# Train : Loss: 0.0004, Train acc1 : 0.8849
# Val : Loss: 0.1784, Val acc1 : 0.4322
# EPOCH  89
# Train : Loss: 0.0007, Train acc1 : 0.8912
# Val : Loss: 0.1655, Val acc1 : 0.4407
# EPOCH  90
# Train : Loss: 0.0001, Train acc1 : 0.8959
# Val : Loss: 0.1618, Val acc1 : 0.4237
# EPOCH  91
# Train : Loss: 0.0001, Train acc1 : 0.8927
# Val : Loss: 0.1759, Val acc1 : 0.4237
# EPOCH  92
# Train : Loss: 0.0001, Train acc1 : 0.8927
# Val : Loss: 0.1739, Val acc1 : 0.4153
# EPOCH  93
# Train : Loss: 0.0001, Train acc1 : 0.8912
# Val : Loss: 0.1718, Val acc1 : 0.4237
# EPOCH  94
# Train : Loss: 0.0001, Train acc1 : 0.8927
# Val : Loss: 0.2089, Val acc1 : 0.4068
# EPOCH  95
# Train : Loss: 0.0001, Train acc1 : 0.8896
# Val : Loss: 0.1897, Val acc1 : 0.4237
# EPOCH  96
# Train : Loss: 0.0010, Train acc1 : 0.8896
# Val : Loss: 0.1729, Val acc1 : 0.4407
# EPOCH  97
# Train : Loss: 0.0002, Train acc1 : 0.8959
# Val : Loss: 0.1397, Val acc1 : 0.4492
# EPOCH  98
# Train : Loss: 0.0002, Train acc1 : 0.8975
# Val : Loss: 0.1640, Val acc1 : 0.4746
# EPOCH  99
# Train : Loss: 0.0001, Train acc1 : 0.9022
# Val : Loss: 0.1709, Val acc1 : 0.4831
# EPOCH  100
# Train : Loss: 0.0001, Train acc1 : 0.9038
# Val : Loss: 0.1586, Val acc1 : 0.4746

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score

modeltest=Classifier()
modeltest.load_state_dict(best_state)
modeltest.cuda()
modeltest.eval()
truth=[]
preds=[]
for minibatch in test_data_loader:
            X_test, Y1_test  = minibatch
            X_test=X_test.cuda()
            Y1_test=Y1_test.cuda()
            output_test = modeltest(X_test.float())
            output_test=output_test.squeeze(1)
            prediction = torch.ge(output_test, 0.5).float()
            truth.extend(Y1_test.tolist())
            preds.extend(prediction.tolist())
acc=accuracy_score(truth,preds)
# print(truth,preds)
tn, fp, fn, tp = confusion_matrix(truth, preds).ravel()
f1score=f1_score(truth, preds)
precision=precision_score(truth, preds)
recall=recall_score(truth,preds)
roc=roc_auc_score(truth,preds)
specificity=tn/(tn+fp)

print('{:.2f} {:.2f} {:.2f} {:.2f} {:.2f} {:.2f}'.format(acc,f1score,precision,recall,roc,specificity))
# Out:
# 0.56 0.55 0.55 0.55 0.56 0.57

# %%
testdataset = load_data("../Participant_wise_physio_change1",'test')

test_data_loader = DataLoader(testdataset,worker_init_fn=seed_worker,shuffle=True,batch_size=batch_size)

modeltest=Classifier()
modeltest.load_state_dict(best_state)
modeltest.cuda()
modeltest.eval()
truth=[]
preds=[]
for minibatch in test_data_loader:
            X_test, Y1_test  = minibatch
            X_test=X_test.cuda()
            Y1_test=Y1_test.cuda()
            output_test = modeltest(X_test.float())
            output_test=output_test.squeeze(1)
            prediction = torch.ge(output_test, 0.5).float()
            truth.extend(Y1_test.tolist())
            preds.extend(prediction.tolist())
acc=accuracy_score(truth,preds)
# print(truth,preds)
tn, fp, fn, tp = confusion_matrix(truth, preds).ravel()
f1score=f1_score(truth, preds)
precision=precision_score(truth, preds)
recall=recall_score(truth,preds)
roc=roc_auc_score(truth,preds)
specificity=tn/(tn+fp)

print('{:.2f} {:.2f} {:.2f} {:.2f} {:.2f} {:.2f}'.format(acc,f1score,precision,recall,roc,specificity))
# Out:
# 0.54 0.54 0.53 0.55 0.54 0.53

# %%
testdataset = load_data("../Participant_wise_physio_change2",'test')

test_data_loader = DataLoader(testdataset,worker_init_fn=seed_worker,shuffle=True,batch_size=batch_size)

modeltest=Classifier()
modeltest.load_state_dict(best_state)
modeltest.cuda()
modeltest.eval()
truth=[]
preds=[]
for minibatch in test_data_loader:
            X_test, Y1_test  = minibatch
            X_test=X_test.cuda()
            Y1_test=Y1_test.cuda()
            output_test = modeltest(X_test.float())
            output_test=output_test.squeeze(1)
            prediction = torch.ge(output_test, 0.5).float()
            truth.extend(Y1_test.tolist())
            preds.extend(prediction.tolist())
acc=accuracy_score(truth,preds)
# print(truth,preds)
tn, fp, fn, tp = confusion_matrix(truth, preds).ravel()
f1score=f1_score(truth, preds)
precision=precision_score(truth, preds)
recall=recall_score(truth,preds)
roc=roc_auc_score(truth,preds)
specificity=tn/(tn+fp)

print('{:.2f} {:.2f} {:.2f} {:.2f} {:.2f} {:.2f}'.format(acc,f1score,precision,recall,roc,specificity))
# Out:
# 0.58 0.56 0.57 0.55 0.58 0.60
