# %%
import math
import pylab
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import numpy as np
from torch.utils import data
import argparse
import torch
import torch.utils.data as data_utils
import torch.optim as optim
from torch.autograd import Variable
import torch
import torch.nn as nn
import torch.nn.functional as F

seed = 2021
torch.manual_seed(seed)
torch.cuda.manual_seed(0)
np.random.seed(seed)


def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    numpy.random.seed(worker_seed)
    random.seed(worker_seed)
torch.backends.cudnn.deterministic = True


class Dataset(data.Dataset):
    def __init__(self, X1, Y1):
        self.X1 = X1
        self.Y1 = Y1

    def __len__(self):
        return len(self.X1)

    def __getitem__(self, index):
        x = self.X1[index]
        y1 = self.Y1[index]
        return x, y1

# %%
from collections import OrderedDict
def init_weights(m):
    if type(m) == nn.Linear:
        torch.nn.init.xavier_uniform_(m.weight)
        m.bias.data.fill_(0.01)
    if type(m) == nn.Conv2d:
        torch.nn.init.xavier_uniform_(m.weight)
        m.bias.data.fill_(0.01)

class Classifier(nn.Module):
    def __init__(self):
        super(Classifier, self).__init__()
        self.L = 128
        self.D = 64
        self.K = 1
        self.feature_size = 24
        self.shared_layer_size = 128

        self.fc = nn.Sequential(
            nn.Conv1d(1, 128, kernel_size=(1,2)),
            nn.ReLU(),
            nn.Conv1d(128, 32, kernel_size=(1,2)),
            nn.ReLU(),
            nn.Linear(6,32),
            nn.ReLU()
          )
        self.fc2 = nn.Sequential(
            nn.Linear(19456, 512),
            nn.BatchNorm1d(512,affine=False),
            nn.ReLU(),
            nn.Linear(512, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 1),
            nn.Sigmoid()
        )


    def forward(self, x):
        
        Y_prob=self.fc(x)
        Y_prob=self.fc2(Y_prob.reshape(Y_prob.size(0),-1))
        
        return Y_prob

# %%
from torch.optim.lr_scheduler import _LRScheduler
class CyclicLR(_LRScheduler):
    
    def __init__(self, optimizer, schedule, last_epoch=-1):
        assert callable(schedule)
        self.schedule = schedule
        super().__init__(optimizer, last_epoch)

    def get_lr(self):
        return [self.schedule(self.last_epoch, lr) for lr in self.base_lrs]

# %%
def cosine(t_max, eta_min=0):
    
    def scheduler(epoch, base_lr):
        t = epoch % t_max
        return eta_min + (base_lr - eta_min)*(1 + np.cos(np.pi*t/t_max))/2
    
    return scheduler

# %%
xTrain=np.load("../extracted_features/Change/input_features_train_grp3.npy")
labels_stress_train=np.load("../extracted_features/Change/labels_stress_train_grp3.npy")
yTrain=np.load("../extracted_features/Change/labels_train_grp3.npy")

xTest=np.load("../extracted_features/Change/input_features_test_grp3.npy")
labels_stress_test=np.load("../extracted_features/Change/labels_stress_test_grp3.npy")
yTest=np.load("../extracted_features/Change/labels_test_grp3.npy")


xVal=np.load("../extracted_features/Change/input_features_val_grp3.npy")
labels_stress_val=np.load("../extracted_features/Change/labels_stress_val_grp3.npy")
yVal=np.load("../extracted_features/Change/labels_val_grp3.npy")


# train_features=np.load("../extracted_features/bl/0/GRP-3/input_features_train_grp3.npy")
# labels_train=np.load("../extracted_features/bl/0/GRP-3/labels_train_grp3.npy")

# test_features=np.load("../extracted_features/bl/0/GRP-3/input_features_test_grp3.npy")
# labels_test=np.load("../extracted_features/bl/0/GRP-3/labels_test_grp3.npy")

# val_features=np.load("../extracted_features/bl/0/GRP-3/input_features_val_grp3.npy")
# labels_val=np.load("../extracted_features/bl/0/GRP-3/labels_val_grp3.npy")

# %%
# print(labels_train.shape,labels_train)

# %%
print(xTrain.shape,yTrain.shape)
print(xTest.shape,yTest.shape)
print(xVal.shape,yVal.shape)
# Out:
# (512, 19, 8) (512,)
# (122, 19, 8) (122,)
# (118, 19, 8) (118,)

# %%
# print(train_features.shape,labels_train.shape)
# print(test_features.shape,labels_test.shape)
# print(val_features.shape,labels_val.shape)

# %%
# train_features=train_features.reshape(len(train_features),1,19,24)
# test_features=test_features.reshape(len(test_features),1,19,24)
# val_features=val_features.reshape(len(val_features),1,19,24)

xTrain = xTrain.reshape(len(xTrain),1,19,8)
xTest = xTest.reshape(len(xTest),1,19,8)
xVal = xVal.reshape(len(xVal),1,19,8)

# %%
# xTrain=np.append(train_features,xTrain,axis=0)
# xTest=np.append(test_features,xTest,axis=0)
# xVal=np.append(val_features,xVal,axis=0)
# yTrain=np.append(labels_train,yTrain,axis=0)
# yTest=np.append(labels_test,yTest,axis=0)
# yVal=np.append(labels_val,yVal,axis=0)

# %%
batch_size=20

train_data = Dataset(xTrain, yTrain)
test_data=Dataset(xTest,yTest)
val_data=Dataset(xVal,yVal)

# train_data = Dataset(train_features, labels_train)
# test_data=Dataset(test_features,labels_test)
# val_data=Dataset(val_features,labels_val)

train_data_loader = DataLoader(train_data,worker_init_fn=seed_worker, shuffle=True, batch_size=batch_size)
val_data_loader=DataLoader(test_data,worker_init_fn=seed_worker,shuffle=True,batch_size=batch_size)
test_data_loader=DataLoader(val_data,worker_init_fn=seed_worker,shuffle=True,batch_size=batch_size)

# %%
for batch in val_data_loader:
    print(batch[1].shape)
    break
print(len(val_data_loader))
# Out:
# torch.Size([20])
# 7

# %%
feature_size = 8
shared_layer_size = 512
LR = 0.0001
epoch = 100
model=Classifier()
model.cuda()
iterations_per_epoch = len(train_data_loader)
model.apply(init_weights)
loss_func = nn.BCELoss()
optimizer = torch.optim.RMSprop(model.parameters(), lr=LR)
sched = CyclicLR(optimizer, cosine(t_max=iterations_per_epoch * 2, eta_min=LR/100))

# %%
from torchsummary import summary
summary(model.cuda(),(1,19,8))
# torch.save(model, "modelarchitect_final.pt")
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv1d-1           [-1, 128, 19, 7]             384
#               ReLU-2           [-1, 128, 19, 7]               0
#             Conv1d-3            [-1, 32, 19, 6]           8,224
#               ReLU-4            [-1, 32, 19, 6]               0
#             Linear-5           [-1, 32, 19, 32]             224
#               ReLU-6           [-1, 32, 19, 32]               0
#             Linear-7                  [-1, 512]       9,961,984
#        BatchNorm1d-8                  [-1, 512]               0
#               ReLU-9                  [-1, 512]               0
#            Linear-10                  [-1, 128]          65,664
#              ReLU-11                  [-1, 128]               0
#            Linear-12                   [-1, 64]           8,256
#              ReLU-13                   [-1, 64]               0
#            Linear-14                    [-1, 1]              65
#           Sigmoid-15                    [-1, 1]               0
# ================================================================
# Total params: 10,044,801
# Trainable params: 10,044,801
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.63
# Params size (MB): 38.32
# Estimated Total Size (MB): 38.95
# ----------------------------------------------------------------

# %%
from sklearn.metrics import accuracy_score
best_acc1 = 0
modelname=[]
truth=[]
preds=[]
model.train()
for it in range(epoch+1):
    total=len(train_data_loader)*batch_size
    train_loss = 0.
    for minibatch in train_data_loader:
        X, Y1  = minibatch
        X=X.cuda()
        Y1=Y1.cuda()
        output = model(X.float())
        output=output.squeeze(1)
        loss = loss_func(output, Y1.float())
        Y_hat1 = torch.ge(output, 0.5).float()
        train_loss += loss.item()
        truth.extend(Y1.tolist())
        preds.extend(Y_hat1.tolist())
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        sched.step()
    trainacc1=accuracy_score(truth,preds)
    train_loss /= total
    print("EPOCH ",it)
    print('Train : Loss: {:.4f}, Train acc1 : {:.4f}'.format(train_loss,trainacc1))
    
    count=0
    val_loss= 0.
    truth=[]
    preds=[]
    total=len(val_data_loader)*batch_size
    model.eval()    
    for minibatch in val_data_loader:
        X_valid, Y1_valid  = minibatch
        X_valid=X_valid.cuda()
        Y1_valid=Y1_valid.cuda()
        output_val = model(X_valid.float())
        output_val=output_val.squeeze(1)
        loss = loss_func(output_val, Y1_valid.float())
        Y_hat1_val = torch.ge(output_val, 0.5).float()
        val_loss += loss.item()
        truth.extend(Y1_valid.tolist())
        preds.extend(Y_hat1_val.tolist())
    valacc1=accuracy_score(truth,preds)
    val_loss /= total
    print('Val : Loss: {:.4f}, Val acc1 : {:.4f}'.format(val_loss,valacc1))
    if valacc1 >= best_acc1:
        best_acc1 = valacc1
        best_state = model.state_dict()
        print('Best validation accuracy1 ', best_acc1)
# Out:
# EPOCH  0
# Train : Loss: 0.0345, Train acc1 : 0.6055
# Val : Loss: 0.0383, Val acc1 : 0.5574
# Best validation accuracy1  0.5573770491803278
# EPOCH  1
# Train : Loss: 0.0252, Train acc1 : 0.7050
# Val : Loss: 0.0345, Val acc1 : 0.5984
# Best validation accuracy1  0.5983606557377049
# EPOCH  2
# Train : Loss: 0.0283, Train acc1 : 0.6703
# Val : Loss: 0.0337, Val acc1 : 0.6066
# Best validation accuracy1  0.6065573770491803
# EPOCH  3
# Train : Loss: 0.0223, Train acc1 : 0.7555
# Val : Loss: 0.0341, Val acc1 : 0.5574
# EPOCH  4
# Train : Loss: 0.0234, Train acc1 : 0.7192
# Val : Loss: 0.0373, Val acc1 : 0.5246
# EPOCH  5
# Train : Loss: 0.0191, Train acc1 : 0.7823
# Val : Loss: 0.0364, Val acc1 : 0.5410
# EPOCH  6
# Train : Loss: 0.0215, Train acc1 : 0.7524
# Val : Loss: 0.0355, Val acc1 : 0.5246
# EPOCH  7
# Train : Loss: 0.0171, Train acc1 : 0.7965
# Val : Loss: 0.0403, Val acc1 : 0.5246
# EPOCH  8
# Train : Loss: 0.0194, Train acc1 : 0.7571
# Val : Loss: 0.0355, Val acc1 : 0.5492
# EPOCH  9
# Train : Loss: 0.0149, Train acc1 : 0.8186
# Val : Loss: 0.0353, Val acc1 : 0.5410
# EPOCH  10
# Train : Loss: 0.0172, Train acc1 : 0.7792
# Val : Loss: 0.0333, Val acc1 : 0.6557
# Best validation accuracy1  0.6557377049180327
# EPOCH  11
# Train : Loss: 0.0130, Train acc1 : 0.8675
# Val : Loss: 0.0386, Val acc1 : 0.5492
# EPOCH  12
# Train : Loss: 0.0163, Train acc1 : 0.8013
# Val : Loss: 0.0368, Val acc1 : 0.5656
# EPOCH  13
# Train : Loss: 0.0111, Train acc1 : 0.8644
# Val : Loss: 0.0440, Val acc1 : 0.5492
# EPOCH  14
# Train : Loss: 0.0134, Train acc1 : 0.8249
# Val : Loss: 0.0461, Val acc1 : 0.5328
# EPOCH  15
# Train : Loss: 0.0095, Train acc1 : 0.8612
# Val : Loss: 0.0406, Val acc1 : 0.5328
# EPOCH  16
# Train : Loss: 0.0131, Train acc1 : 0.8249
# Val : Loss: 0.0421, Val acc1 : 0.5574
# EPOCH  17
# Train : Loss: 0.0083, Train acc1 : 0.8770
# Val : Loss: 0.0476, Val acc1 : 0.5492
# EPOCH  18
# Train : Loss: 0.0097, Train acc1 : 0.8580
# Val : Loss: 0.0609, Val acc1 : 0.5082
# EPOCH  19
# Train : Loss: 0.0068, Train acc1 : 0.8801
# Val : Loss: 0.0488, Val acc1 : 0.5492
# EPOCH  20
# Train : Loss: 0.0113, Train acc1 : 0.8438
# Val : Loss: 0.0631, Val acc1 : 0.5656
# EPOCH  21
# Train : Loss: 0.0063, Train acc1 : 0.8943
# Val : Loss: 0.0493, Val acc1 : 0.5902
# EPOCH  22
# Train : Loss: 0.0088, Train acc1 : 0.8785
# Val : Loss: 0.0535, Val acc1 : 0.5164
# EPOCH  23
# Train : Loss: 0.0050, Train acc1 : 0.8927
# Val : Loss: 0.0567, Val acc1 : 0.5902
# EPOCH  24
# Train : Loss: 0.0095, Train acc1 : 0.8580
# Val : Loss: 0.0500, Val acc1 : 0.5574
# EPOCH  25
# Train : Loss: 0.0042, Train acc1 : 0.9054
# Val : Loss: 0.0523, Val acc1 : 0.5820
# EPOCH  26
# Train : Loss: 0.0051, Train acc1 : 0.9054
# Val : Loss: 0.0446, Val acc1 : 0.6311
# EPOCH  27
# Train : Loss: 0.0029, Train acc1 : 0.9259
# Val : Loss: 0.0632, Val acc1 : 0.5902
# EPOCH  28
# Train : Loss: 0.0058, Train acc1 : 0.8927
# Val : Loss: 0.0486, Val acc1 : 0.5902
# EPOCH  29
# Train : Loss: 0.0029, Train acc1 : 0.9196
# Val : Loss: 0.0448, Val acc1 : 0.6066
# EPOCH  30
# Train : Loss: 0.0044, Train acc1 : 0.9054
# Val : Loss: 0.0499, Val acc1 : 0.5902
# EPOCH  31
# Train : Loss: 0.0021, Train acc1 : 0.9196
# Val : Loss: 0.0581, Val acc1 : 0.5984
# EPOCH  32
# Train : Loss: 0.0038, Train acc1 : 0.9069
# Val : Loss: 0.0739, Val acc1 : 0.5902
# EPOCH  33
# Train : Loss: 0.0017, Train acc1 : 0.9211
# Val : Loss: 0.0559, Val acc1 : 0.5984
# EPOCH  34
# Train : Loss: 0.0019, Train acc1 : 0.9196
# Val : Loss: 0.0859, Val acc1 : 0.5656
# EPOCH  35
# Train : Loss: 0.0012, Train acc1 : 0.9164
# Val : Loss: 0.0621, Val acc1 : 0.5820
# EPOCH  36
# Train : Loss: 0.0095, Train acc1 : 0.8644
# Val : Loss: 0.0426, Val acc1 : 0.5820
# EPOCH  37
# Train : Loss: 0.0030, Train acc1 : 0.9196
# Val : Loss: 0.0558, Val acc1 : 0.5656
# EPOCH  38
# Train : Loss: 0.0026, Train acc1 : 0.9117
# Val : Loss: 0.0514, Val acc1 : 0.5574
# EPOCH  39
# Train : Loss: 0.0010, Train acc1 : 0.9148
# Val : Loss: 0.0569, Val acc1 : 0.5738
# EPOCH  40
# Train : Loss: 0.0010, Train acc1 : 0.9180
# Val : Loss: 0.0543, Val acc1 : 0.5902
# EPOCH  41
# Train : Loss: 0.0006, Train acc1 : 0.9211
# Val : Loss: 0.0566, Val acc1 : 0.5738
# EPOCH  42
# Train : Loss: 0.0007, Train acc1 : 0.9180
# Val : Loss: 0.0605, Val acc1 : 0.5738
# EPOCH  43
# Train : Loss: 0.0005, Train acc1 : 0.9180
# Val : Loss: 0.0730, Val acc1 : 0.5574
# EPOCH  44
# Train : Loss: 0.0005, Train acc1 : 0.9148
# Val : Loss: 0.0630, Val acc1 : 0.5738
# EPOCH  45
# Train : Loss: 0.0004, Train acc1 : 0.9180
# Val : Loss: 0.0663, Val acc1 : 0.5902
# EPOCH  46
# Train : Loss: 0.0004, Train acc1 : 0.9211
# Val : Loss: 0.0882, Val acc1 : 0.5738
# EPOCH  47
# Train : Loss: 0.0003, Train acc1 : 0.9180
# Val : Loss: 0.0651, Val acc1 : 0.5820
# EPOCH  48
# Train : Loss: 0.0316, Train acc1 : 0.8091
# Val : Loss: 0.0430, Val acc1 : 0.5574
# EPOCH  49
# Train : Loss: 0.0059, Train acc1 : 0.8959
# Val : Loss: 0.0405, Val acc1 : 0.5902
# EPOCH  50
# Train : Loss: 0.0043, Train acc1 : 0.9117
# Val : Loss: 0.0502, Val acc1 : 0.5820
# EPOCH  51
# Train : Loss: 0.0016, Train acc1 : 0.9196
# Val : Loss: 0.0556, Val acc1 : 0.5738
# EPOCH  52
# Train : Loss: 0.0015, Train acc1 : 0.9180
# Val : Loss: 0.0548, Val acc1 : 0.5984
# EPOCH  53
# Train : Loss: 0.0008, Train acc1 : 0.9227
# Val : Loss: 0.0716, Val acc1 : 0.5738
# EPOCH  54
# Train : Loss: 0.0008, Train acc1 : 0.9180
# Val : Loss: 0.0906, Val acc1 : 0.5820
# EPOCH  55
# Train : Loss: 0.0005, Train acc1 : 0.9196
# Val : Loss: 0.0750, Val acc1 : 0.5902
# EPOCH  56
# Train : Loss: 0.0005, Train acc1 : 0.9211
# Val : Loss: 0.0650, Val acc1 : 0.5738
# EPOCH  57
# Train : Loss: 0.0004, Train acc1 : 0.9180
# Val : Loss: 0.0704, Val acc1 : 0.6066
# EPOCH  58
# Train : Loss: 0.0004, Train acc1 : 0.9243
# Val : Loss: 0.0654, Val acc1 : 0.5656
# EPOCH  59
# Train : Loss: 0.0003, Train acc1 : 0.9164
# Val : Loss: 0.0905, Val acc1 : 0.5902
# EPOCH  60
# Train : Loss: 0.0003, Train acc1 : 0.9211
# Val : Loss: 0.0711, Val acc1 : 0.5656
# EPOCH  61
# Train : Loss: 0.0002, Train acc1 : 0.9164
# Val : Loss: 0.0644, Val acc1 : 0.5902
# EPOCH  62
# Train : Loss: 0.0002, Train acc1 : 0.9211
# Val : Loss: 0.0720, Val acc1 : 0.5902
# EPOCH  63
# Train : Loss: 0.0001, Train acc1 : 0.9211
# Val : Loss: 0.0747, Val acc1 : 0.5820
# EPOCH  64
# Train : Loss: 0.0002, Train acc1 : 0.9196
# Val : Loss: 0.0739, Val acc1 : 0.6066
# EPOCH  65
# Train : Loss: 0.0001, Train acc1 : 0.9243
# Val : Loss: 0.0687, Val acc1 : 0.5902
# EPOCH  66
# Train : Loss: 0.0144, Train acc1 : 0.8754
# Val : Loss: 0.0481, Val acc1 : 0.6066
# EPOCH  67
# Train : Loss: 0.0023, Train acc1 : 0.9211
# Val : Loss: 0.0602, Val acc1 : 0.5738
# EPOCH  68
# Train : Loss: 0.0012, Train acc1 : 0.9164
# Val : Loss: 0.0823, Val acc1 : 0.5820
# EPOCH  69
# Train : Loss: 0.0005, Train acc1 : 0.9196
# Val : Loss: 0.0655, Val acc1 : 0.5902
# EPOCH  70
# Train : Loss: 0.0004, Train acc1 : 0.9211
# Val : Loss: 0.0664, Val acc1 : 0.5656
# EPOCH  71
# Train : Loss: 0.0002, Train acc1 : 0.9164
# Val : Loss: 0.0660, Val acc1 : 0.5738
# EPOCH  72
# Train : Loss: 0.0002, Train acc1 : 0.9180
# Val : Loss: 0.0749, Val acc1 : 0.5656
# EPOCH  73
# Train : Loss: 0.0002, Train acc1 : 0.9164
# Val : Loss: 0.0738, Val acc1 : 0.5656
# EPOCH  74
# Train : Loss: 0.0002, Train acc1 : 0.9164
# Val : Loss: 0.0718, Val acc1 : 0.5656
# EPOCH  75
# Train : Loss: 0.0001, Train acc1 : 0.9164
# Val : Loss: 0.0858, Val acc1 : 0.5656
# EPOCH  76
# Train : Loss: 0.0001, Train acc1 : 0.9164
# Val : Loss: 0.0693, Val acc1 : 0.5820
# EPOCH  77
# Train : Loss: 0.0001, Train acc1 : 0.9196
# Val : Loss: 0.0701, Val acc1 : 0.5820
# EPOCH  78
# Train : Loss: 0.0001, Train acc1 : 0.9196
# Val : Loss: 0.0866, Val acc1 : 0.5820
# EPOCH  79
# Train : Loss: 0.0001, Train acc1 : 0.9196
# Val : Loss: 0.0727, Val acc1 : 0.5902
# EPOCH  80
# Train : Loss: 0.0001, Train acc1 : 0.9211
# Val : Loss: 0.0753, Val acc1 : 0.5902
# EPOCH  81
# Train : Loss: 0.0001, Train acc1 : 0.9211
# Val : Loss: 0.0879, Val acc1 : 0.5984
# EPOCH  82
# Train : Loss: 0.0001, Train acc1 : 0.9227
# Val : Loss: 0.0969, Val acc1 : 0.5984
# EPOCH  83
# Train : Loss: 0.0000, Train acc1 : 0.9227
# Val : Loss: 0.1057, Val acc1 : 0.6066
# EPOCH  84
# Train : Loss: 0.0000, Train acc1 : 0.9243
# Val : Loss: 0.0953, Val acc1 : 0.5820
# EPOCH  85
# Train : Loss: 0.0000, Train acc1 : 0.9196
# Val : Loss: 0.0923, Val acc1 : 0.6066
# EPOCH  86
# Train : Loss: 0.0000, Train acc1 : 0.9243
# Val : Loss: 0.0980, Val acc1 : 0.5902
# EPOCH  87
# Train : Loss: 0.0000, Train acc1 : 0.9211
# Val : Loss: 0.0975, Val acc1 : 0.5984
# EPOCH  88
# Train : Loss: 0.0000, Train acc1 : 0.9227
# Val : Loss: 0.1230, Val acc1 : 0.6066
# EPOCH  89
# Train : Loss: 0.0000, Train acc1 : 0.9243
# Val : Loss: 0.1011, Val acc1 : 0.5984
# EPOCH  90
# Train : Loss: 0.0000, Train acc1 : 0.9227
# Val : Loss: 0.1131, Val acc1 : 0.5984
# EPOCH  91
# Train : Loss: 0.0000, Train acc1 : 0.9227
# Val : Loss: 0.0830, Val acc1 : 0.5984
# EPOCH  92
# Train : Loss: 0.0000, Train acc1 : 0.9227
# Val : Loss: 0.1112, Val acc1 : 0.5820
# EPOCH  93
# Train : Loss: 0.0000, Train acc1 : 0.9196
# Val : Loss: 0.1035, Val acc1 : 0.5902
# EPOCH  94
# Train : Loss: 0.0000, Train acc1 : 0.9211
# Val : Loss: 0.0875, Val acc1 : 0.5738
# EPOCH  95
# Train : Loss: 0.0000, Train acc1 : 0.9180
# Val : Loss: 0.0954, Val acc1 : 0.5984
# EPOCH  96
# Train : Loss: 0.0229, Train acc1 : 0.8785
# Val : Loss: 0.0842, Val acc1 : 0.5656
# EPOCH  97
# Train : Loss: 0.0024, Train acc1 : 0.9117
# Val : Loss: 0.0791, Val acc1 : 0.5738
# EPOCH  98
# Train : Loss: 0.0006, Train acc1 : 0.9164
# Val : Loss: 0.0892, Val acc1 : 0.6066
# EPOCH  99
# Train : Loss: 0.0002, Train acc1 : 0.9243
# Val : Loss: 0.0984, Val acc1 : 0.6148
# EPOCH  100
# Train : Loss: 0.0002, Train acc1 : 0.9259
# Val : Loss: 0.0743, Val acc1 : 0.5984

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score

modeltest=Classifier()
modeltest.load_state_dict(best_state)
modeltest.cuda()
modeltest.eval()
truth=[]
preds=[]
for minibatch in test_data_loader:
            X_test, Y1_test  = minibatch
            X_test=X_test.cuda()
            Y1_test=Y1_test.cuda()
            output_test = modeltest(X_test.float())
            output_test=output_test.squeeze(1)
            prediction = torch.ge(output_test, 0.5).float()
            truth.extend(Y1_test.tolist())
            preds.extend(prediction.tolist())
acc=accuracy_score(truth,preds)
# print(truth,preds)
tn, fp, fn, tp = confusion_matrix(truth, preds).ravel()
f1score=f1_score(truth, preds)
precision=precision_score(truth, preds)
recall=recall_score(truth,preds)
roc=roc_auc_score(truth,preds)
specificity=tn/(tn+fp)

print('{:.2f} {:.2f} {:.2f} {:.2f} {:.2f} {:.2f}'.format(acc,f1score,precision,recall,roc,specificity))
# Out:
# 0.51 0.38 0.50 0.31 0.51 0.70

# %%
xTest=np.load("../extracted_features/Change1/input_features_val_grp3.npy")
yTest=np.load("../extracted_features/Change1/labels_val_grp3.npy")

xTest = xTest.reshape(len(xTest),1,19,8)

testdataset = Dataset(xTest,yTest)

test_data_loader = DataLoader(testdataset,worker_init_fn=seed_worker,shuffle=True,batch_size=batch_size)

modeltest=Classifier()
modeltest.load_state_dict(best_state)
modeltest.cuda()
modeltest.eval()
truth=[]
preds=[]
for minibatch in test_data_loader:
            X_test, Y1_test  = minibatch
            X_test=X_test.cuda()
            Y1_test=Y1_test.cuda()
            output_test = modeltest(X_test.float())
            output_test=output_test.squeeze(1)
            prediction = torch.ge(output_test, 0.5).float()
            truth.extend(Y1_test.tolist())
            preds.extend(prediction.tolist())
acc=accuracy_score(truth,preds)
# print(truth,preds)
tn, fp, fn, tp = confusion_matrix(truth, preds).ravel()
f1score=f1_score(truth, preds)
precision=precision_score(truth, preds)
recall=recall_score(truth,preds)
roc=roc_auc_score(truth,preds)
specificity=tn/(tn+fp)

print('{:.2f} {:.2f} {:.2f} {:.2f} {:.2f} {:.2f}'.format(acc,f1score,precision,recall,roc,specificity))
# Out:
# 0.47 0.34 0.44 0.28 0.47 0.67
